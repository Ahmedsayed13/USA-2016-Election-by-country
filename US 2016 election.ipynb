# %% [markdown]
# ### 2016 US Election by Country Analysis
# #### By: Ahmed Sayed

# %%
import pandas as pd
import numpy 
import matplotlib.pyplot as plt

# %%
election2016=pd.read_csv('us-2016-primary-results.csv',sep=';')

# %%
election2016.head()
# Out:
#      state state_abbreviation         county        fips       party  \
# 0  Vermont                 VT         Sutton  95000197.0  Republican
# 1  Vermont                 VT      Tunbridge  95000204.0  Republican
# 2  Vermont                 VT  Weathersfield  95000220.0  Republican
# 3  Vermont                 VT         Weston  95000228.0  Republican
# 4  Vermont                 VT        Whiting  95000233.0  Republican
#
#      candidate  votes  fraction_votes
# 0  John Kasich     20           0.227
# 1  John Kasich     36           0.319
# 2     Ted Cruz     46           0.111
# 3  John Kasich     32           0.471
# 4   Ben Carson      0           0.000

# %% [markdown]
# ### Assess data
# - Quality issues :
# county column name
# - Tidiness issue
# state and state_abbreviations are two columns that represnt the same value

# %%
election2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24611 entries, 0 to 24610
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               24611 non-null  object
#  1   state_abbreviation  24611 non-null  object
#  2   county              24611 non-null  object
#  3   fips                24511 non-null  float64
#  4   party               24611 non-null  object
#  5   candidate           24611 non-null  object
#  6   votes               24611 non-null  int64
#  7   fraction_votes      24611 non-null  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Clean data

# %% [markdown]
# - Define:
# Change column name of county into country

# %% [markdown]
# - Code

# %%
election2016.rename(columns={'county':'country'},inplace=True)

# %% [markdown]
# - Test

# %%
election2016.head()
# Out:
#      state state_abbreviation        country        fips       party  \
# 0  Vermont                 VT         Sutton  95000197.0  Republican
# 1  Vermont                 VT      Tunbridge  95000204.0  Republican
# 2  Vermont                 VT  Weathersfield  95000220.0  Republican
# 3  Vermont                 VT         Weston  95000228.0  Republican
# 4  Vermont                 VT        Whiting  95000233.0  Republican
#
#      candidate  votes  fraction_votes
# 0  John Kasich     20           0.227
# 1  John Kasich     36           0.319
# 2     Ted Cruz     46           0.111
# 3  John Kasich     32           0.471
# 4   Ben Carson      0           0.000

# %% [markdown]
# - Define : drop state_abbreviation column

# %% [markdown]
# - Code

# %%
election2016.drop(['state_abbreviation'],axis=1,inplace=True)

# %% [markdown]
# - test

# %%
election2016.head()
# Out:
#      state        country        fips       party    candidate  votes  \
# 0  Vermont         Sutton  95000197.0  Republican  John Kasich     20
# 1  Vermont      Tunbridge  95000204.0  Republican  John Kasich     36
# 2  Vermont  Weathersfield  95000220.0  Republican     Ted Cruz     46
# 3  Vermont         Weston  95000228.0  Republican  John Kasich     32
# 4  Vermont        Whiting  95000233.0  Republican   Ben Carson      0
#
#    fraction_votes
# 0           0.227
# 1           0.319
# 2           0.111
# 3           0.471
# 4           0.000

# %%
election2016.state.nunique()
# Out:
# 49

# %%
election2016.country.nunique()
# Out:
# 2633

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
vermont2016=election2016[election2016['state'] == 'Vermont']

# %%
vermont2016.head()
# Out:
#      state        country        fips       party    candidate  votes  \
# 0  Vermont         Sutton  95000197.0  Republican  John Kasich     20
# 1  Vermont      Tunbridge  95000204.0  Republican  John Kasich     36
# 2  Vermont  Weathersfield  95000220.0  Republican     Ted Cruz     46
# 3  Vermont         Weston  95000228.0  Republican  John Kasich     32
# 4  Vermont        Whiting  95000233.0  Republican   Ben Carson      0
#
#    fraction_votes
# 0           0.227
# 1           0.319
# 2           0.111
# 3           0.471
# 4           0.000

# %%
vermont2016.candidate.unique()
# Out:
# array(['John Kasich', 'Ted Cruz', 'Ben Carson', 'Donald Trump',
#        'Marco Rubio', 'Bernie Sanders', 'Hillary Clinton'], dtype=object)

# %%
vermont2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Vermont',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Vermont')

# %%
virginia2016=election2016[election2016['state']=='Virginia']

# %%
virginia2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Virginia',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Virginia')

# %%
washington2016=election2016[election2016['state']=='Washington']
washington2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('Washington',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Washington')

# %%
west_virginia2016=election2016[election2016['state']=='West Virginia']

# %%
west_virginia2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('West Virginia',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'West Virginia')

# %%
wisconsin2016=election2016[election2016['state']== 'Wisconsin']

# %%
wisconsin2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Wisconsin',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Wisconsin')

# %%
wyoming=election2016[election2016['state']== 'Wyoming']

# %%
wyoming.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='black')
plt.title('Wyoming',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Wyoming')

# %%
alabama2016=election2016[election2016['state']=='Alabama']

# %%
alabama2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Alabama',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Alabama')

# %%
alaska2016=election2016[election2016['state']=='Alaska']

# %%
alaska2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='black')
plt.title('Alaska',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Alaska')

# %%
arizona2016=election2016[election2016['state']=='Arizona']

# %%
arizona2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Arizona',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Arizona')

# %%
arkansas2016=election2016[election2016['state']=='Arkansas']

# %%
arkansas2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Arkansas',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Arkansas')

# %%
california2016=election2016[election2016['state']=='California']

# %%
california2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('California',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'California')

# %%
colorado2016=election2016[election2016['state']=='Colorado']

# %%
colorado2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Colorado',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Colorado')

# %%
colorado2016.candidate.unique()
# Out:
# array(['Bernie Sanders', 'Hillary Clinton'], dtype=object)

# %%
connecticut2016=election2016[election2016['state']=='Connecticut']

# %%
connecticut2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Connecticut',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Connecticut')

# %%
florida2016=election2016[election2016['state']=='Florida']

# %%
florida2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Florida',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Florida')

# %%
georgia2016=election2016[election2016['state']=='Georgia']

# %%
georgia2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Georgia',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Georgia')

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
hawaii2016=election2016[election2016['state']=='Hawaii']

# %%
hawaii2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Hawaii',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Hawaii')

# %%
idaho2016=election2016[election2016['state']=='Idaho']

# %%
idaho2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='black')
plt.title('Idaho',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Idaho')

# %%
illinois2016=election2016[election2016['state']=='Illinois']

# %%
illinois2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Illinois',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Illinois')

# %%
indiana2016=election2016[election2016['state']=='Indiana']

# %%
indiana2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('Indiana',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Indiana')

# %%
iowa2016=election2016[election2016['state']=='Iowa']

# %%
iowa2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Iowa',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Iowa')

# %%
kansas2016=election2016[election2016['state']=='Kansas']

# %%
kansas2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='black')
plt.title('Kansas',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Kansas')

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
michigan2016=election2016[election2016['state']=='Michigan']

# %%
michigan2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Michigan',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Michigan')

# %%
mississippi2016=election2016[election2016['state']=='Mississippi']

# %%
mississippi2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Mississippi',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Mississippi')

# %%
missouri2016=election2016[election2016['state']=='Missouri']

# %%
missouri2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Missouri',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Missouri')

# %%
montana2016=election2016[election2016['state']=='Montana']

# %%
montana2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('Montana',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Montana')

# %%
nebraska2016=election2016[election2016['state']=='Nebraska']

# %%
nebraska2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('Nebraska',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Nebraska')

# %%
kentucky2016=election2016[election2016['state']=='Kentucky']

# %%
kentucky2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Kentucky',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Kentucky')

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
louisiana2016=election2016[election2016['state']=='Louisiana']

# %%
louisiana2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('louisiana',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'louisiana')

# %%
maine2016=election2016[election2016['state']=='Maine']

# %%
maine2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Maine',fontweight='bold',)
# Out:
# Text(0.5, 1.0, 'Maine')

# %%
maine2016.candidate.nunique()
# Out:
# 2

# %%
maryland2016=election2016[election2016['state']=='Maryland']

# %%
maryland2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Maryland',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Maryland')

# %%
massachusetts2016=election2016[election2016['state']=='Massachusetts']

# %%
massachusetts2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Massachusetts',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Massachusetts')

# %%
nevada2016=election2016[election2016['state']=='Nevada']

# %%
nevada2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Nevada',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Nevada')

# %%
new_Hampshire2016=election2016[election2016['state']=='New Hampshire']

# %%
new_Hampshire2016.groupby('candidate')['votes'].sum().sort_values()[:-5].plot(kind='bar',figsize=(5,5),color='grey')
plt.title('New Hampshire',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'New Hampshire')

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
new_Jersey2016=election2016[election2016['state']=='New Jersey']

# %%
new_Jersey2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('New Jersey',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'New Jersey')

# %%
new_Mexico2016=election2016[election2016['state']=='New Mexico']

# %%
new_Mexico2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('New Mexico',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'New Mexico')

# %%
new_York2016=election2016[election2016['state']=='New York']

# %%
new_York2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('New York',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'New York')

# %%
north_Carolina2016=election2016[election2016['state']=='North Carolina']

# %%
north_Carolina2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('North Carolina',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'North Carolina')

# %%
north_Dakota2016=election2016[election2016['state']=='North Dakota']

# %%
north_Dakota2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('North Dakota',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'North Dakota')

# %%
election2016.state.unique()
# Out:
# array(['Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Delaware'], dtype=object)

# %%
ohio2016=election2016[election2016['state']=='Ohio']

# %%
ohio2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='green')
plt.title('Ohio',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Ohio')

# %%
oklahoma2016=election2016[election2016['state']=='Oklahoma']

# %%
oklahoma2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Oklahoma',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Oklahoma')

# %%
oregon2016=election2016[election2016['state']=='Oregon']

# %%
oregon2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Oregon',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Oregon')

# %%
pennsylvania2016=election2016[election2016['state']=='Pennsylvania']

# %%
pennsylvania2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Pennsylvania',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Pennsylvania')

# %%
Rhode_Island2016=election2016[election2016['state']=='Rhode Island']

# %%
Rhode_Island2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='purple')
plt.title('Rhode Island',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Rhode Island')

# %%
South_Carolina2016=election2016[election2016['state']=='South Carolina']

# %%
South_Carolina2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='blue')
plt.title('South Carolina',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'South Carolina')

# %%
South_Dakota2016=election2016[election2016['state']=='South Dakota']

# %%
South_Dakota2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='red')
plt.title('South Dakota',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'South Dakota')

# %%
tennessee2016=election2016[election2016['state']=='Tennessee']

# %%
tennessee2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='red')
plt.title('Tennessee',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Tennessee')

# %%
Texas2016=election2016[election2016['state']=='Texas']

# %%
Texas2016.groupby('candidate')['votes'].sum().sort_values()[-5:].plot(kind='bar',figsize=(5,5),color='black')
plt.title('Texas',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Texas')

# %%
Utah2016=election2016[election2016['state']=='Utah']

# %%
Utah2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='black')
plt.title('Utah',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Utah')

# %%
Delaware2016=election2016[election2016['state']=='Delaware']

# %%
Delaware2016.groupby('candidate')['votes'].sum().sort_values().plot(kind='bar',figsize=(5,5),color='blue')
plt.title('Delaware',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Delaware')
